# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('CustomerChurnDataset\customer_churn_dataset-testing-master.csv')

# %%
df.head()
# Out:
#    CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0           1   22  Female      25               14              4
# 1           2   41  Female      28               28              7
# 2           3   47    Male      27               10              2
# 3           4   35    Male       9               12              5
# 4           5   53  Female      58               24              9
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0             27             Basic         Monthly          598
# 1             13          Standard         Monthly          584
# 2             29           Premium          Annual          757
# 3             17           Premium       Quarterly          232
# 4              2          Standard          Annual          533
#
#    Last Interaction  Churn
# 0                 9      1
# 1                20      0
# 2                21      0
# 3                18      0
# 4                18      0

# %%
df['Subscription Type'].unique()
# Out:
# array(['Basic', 'Standard', 'Premium'], dtype=object)

# %%
df['Contract Length'].unique()
# Out:
# array(['Monthly', 'Annual', 'Quarterly'], dtype=object)

# %%
subscription_type_mapping = {'Basic':1,'Standard':2,'Premium':3}
contract_length_mapping = {'Monthly':1,'Quarterly':3,'Annual':12}
gender_mapping = {'Male':1,'Female':0}

# %%
df['Subscription Type'] = df['Subscription Type'].map(subscription_type_mapping)
df['Contract Length'] = df['Contract Length'].map(contract_length_mapping)
df['Gender'] = df['Gender'].map(gender_mapping)

# %%
df.head()
# Out:
#    CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0           1   22       0      25               14              4
# 1           2   41       0      28               28              7
# 2           3   47       1      27               10              2
# 3           4   35       1       9               12              5
# 4           5   53       0      58               24              9
#
#    Payment Delay  Subscription Type  Contract Length  Total Spend  \
# 0             27                  1                1          598
# 1             13                  2                1          584
# 2             29                  3               12          757
# 3             17                  3                3          232
# 4              2                  2               12          533
#
#    Last Interaction  Churn
# 0                 9      1
# 1                20      0
# 2                21      0
# 3                18      0
# 4                18      0

# %%
df.isnull().sum()
# Out:
# CustomerID           0
# Age                  0
# Gender               0
# Tenure               0
# Usage Frequency      0
# Support Calls        0
# Payment Delay        0
# Subscription Type    0
# Contract Length      0
# Total Spend          0
# Last Interaction     0
# Churn                0
# dtype: int64

# %%
# df.describe()
# Out:
#          CustomerID           Age        Gender        Tenure  \
# count  64374.000000  64374.000000  64374.000000  64374.000000
# mean   32187.500000     41.970982      0.466353     31.994827
# std    18583.317451     13.924911      0.498870     17.098234
# min        1.000000     18.000000      0.000000      1.000000
# 25%    16094.250000     30.000000      0.000000     18.000000
# 50%    32187.500000     42.000000      0.000000     33.000000
# 75%    48280.750000     54.000000      1.000000     47.000000
# max    64374.000000     65.000000      1.000000     60.000000
#
#        Usage Frequency  Support Calls  Payment Delay  Subscription Type  \
# count     64374.000000   64374.000000   64374.000000       64374.000000
# mean         15.080234       5.400690      17.133952           1.999534
# std           8.816470       3.114005       8.852211           0.816084
# min           1.000000       0.000000       0.000000           1.000000
# 25%           7.000000       3.000000      10.000000           1.000000
# 50%          15.000000       6.000000      19.000000           2.000000
# 75%          23.000000       8.000000      25.000000           3.000000
# max          30.000000      10.000000      30.000000           3.000000
#
#        Contract Length   Total Spend  Last Interaction         Churn
# count     64374.000000  64374.000000      64374.000000  64374.000000
# mean          5.305745    541.023379         15.498850      0.473685
# std           4.795685    260.874809          8.638436      0.499311
# min           1.000000    100.000000          1.000000      0.000000
# 25%           1.000000    313.000000          8.000000      0.000000
# 50%           3.000000    534.000000         15.000000      0.000000
# 75%          12.000000    768.000000         23.000000      1.000000
# max          12.000000   1000.000000         30.000000      1.000000

# %%
df['Churn'].value_counts()
